# %% [markdown]
# # تحلیل آماری

# %%
import numpy as np
import pandas as pd
data = pd.read_csv('C:\\Users\\sh.noori\\Desktop\\president_heights.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17076/1106944000.py in <module>
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 data = pd.read_csv('C:\\Users\\sh.noori\\Desktop\\president_heights.csv')
#       4 data
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
print("Mean height: ", heights.mean())
print("Standard deviation:", heights.std())
print("Minimum height: ", heights.min())
print("Maximum height: ", heights.max())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17076/2065514049.py in <module>
# ----> 1 print("Mean height: ", heights.mean())
#       2 print("Standard deviation:", heights.std())
#       3 print("Minimum height: ", heights.min())
#       4 print("Maximum height: ", heights.max())
#
# NameError: name 'heights' is not defined

# %%
data.describe()
# Out:
#            order  height(cm)
# count  42.000000   42.000000
# mean   22.476190  179.738095
# std    13.152461    7.015869
# min     1.000000  163.000000
# 25%    11.250000  174.250000
# 50%    22.000000  182.000000
# 75%    33.750000  183.000000
# max    44.000000  193.000000

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set() # set plot style

# %%
import matplotlib.pyplot as plt
plt.hist(heights)
plt.title('Height Distribution of US Presidents')
plt.xlabel('height (cm)')
plt.ylabel('number');

# %%
data2 = pd.read_csv('C:\\Users\\sh.noori\\Desktop\\iris.csv')
data2
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# 5             5.4          3.9           1.7          0.4     Setosa
# 6             4.6          3.4           1.4          0.3     Setosa
# 7             5.0          3.4           1.5          0.2     Setosa
# 8             4.4          2.9           1.4          0.2     Setosa
# 9             4.9          3.1           1.5          0.1     Setosa
# 10            5.4          3.7           1.5          0.2     Setosa
# 11            4.8          3.4           1.6          0.2     Setosa
# 12            4.8          3.0           1.4          0.1     Setosa
# ...

# %%
shape = data2.shape 
shape
# Out:
# (150, 5)

# %%
data2.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(data2.groupby('variety').size())
print(data2.groupby('variety').median())
print(data2.groupby('variety').mean())
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# dtype: int64
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               5.0          3.4          1.50          0.2
# Versicolor           5.9          2.8          4.35          1.3
# Virginica            6.5          3.0          5.55          2.0
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa             5.006        3.428         1.462        0.246
# Versicolor         5.936        2.770         4.260        1.326
# Virginica          6.588        2.974         5.552        2.026

# %% [markdown]
#      """
#     np.sum              Compute sum of elements
#     np.mean             Compute median of elements
#     np.std              Compute standard deviation
#     np.var              Compute variance
#     np.min              Find minimum value
#     np.max              Find maximum value
#     np.argmin           Find index of minimum value
#     np.argmax           Find index of maximum value
#     np.median           Compute median of elements
#
#      """

# %%
np.log(data2['sepal.length'])
# Out:
# 0      1.629241
# 1      1.589235
# 2      1.547563
# 3      1.526056
# 4      1.609438
# 5      1.686399
# 6      1.526056
# 7      1.609438
# 8      1.481605
# 9      1.589235
# 10     1.686399
# 11     1.568616
# 12     1.568616
# 13     1.458615
# 14     1.757858
# 15     1.740466
# 16     1.686399
# 17     1.629241
# 18     1.740466
# 19     1.629241
# 20     1.686399
# 21     1.629241
# 22     1.526056
# 23     1.629241
# 24     1.568616
# 25     1.609438
# 26     1.609438
# 27     1.648659
# 28     1.648659
# 29     1.547563
#          ...
# 120    1.931521
# 121    1.722767
# 122    2.041220
# 123    1.840550
# 124    1.902108
# 125    1.974081
# 126    1.824549
# 127    1.808289
# 128    1.856298
# 129    1.974081
# 130    2.001480
# 131    2.066863
# 132    1.856298
# 133    1.840550
# 134    1.808289
# 135    2.041220
# 136    1.840550
# 137    1.856298
# 138    1.791759
# 139    1.931521
# 140    1.902108
# 141    1.931521
# 142    1.757858
# 143    1.916923
# ...

# %%
np.corrcoef(data2['sepal.length'], data2['sepal.width'])
# Out:
# array([[ 1.        , -0.11756978],
#        [-0.11756978,  1.        ]])

# %%
# Pairwise Pearson correlations
from pandas import read_csv
from pandas import set_option
filename = "C:\\Users\\ShahinN\\Desktop\\diabetes.csv"
data = read_csv(filename)
correlations = data.corr(method='pearson')
print(correlations)
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
data2 = pd.read_excel('C:\\Users\\sh.noori\\Desktop\\Global Superstore Orders 2016.xlsx')

# %%
data2.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#         ...         Product ID    Category Sub-Category  \
# ...

# %%
pd.crosstab(data2.Segment, data2.Category, values=data2.Profit, aggfunc='mean')
# Out:
# Category     Furniture  Office Supplies  Technology
# Segment
# Consumer     30.201104        15.666895   64.955502
# Corporate    27.825638        17.887266   62.240310
# Home Office  27.053499        16.984667   72.298209

# %%
pd.crosstab(data2.Segment, [data2.Category, data2.Market], values=data2.Profit, aggfunc='max' )
# Out:
# Category    Furniture                                            \
# Market         Africa Asia Pacific   Europe    LATAM       USCA
# Segment
# Consumer      1523.52      2316.51  2071.44  1313.28   770.3520
# Corporate      938.70      2097.03  1868.13   923.44  1013.1270
# Home Office   1098.24       925.44   845.70   996.60   746.4078
#
# Category    Office Supplies                                          \
# Market               Africa Asia Pacific   Europe   LATAM      USCA
# Segment
# Consumer             818.28      1236.96  1989.54  999.36  4946.370
# Corporate            484.44      1440.24  3979.08  861.48  1906.485
# Home Office          779.52      1722.48  1898.40  887.60  1906.485
#
# Category    Technology
# Market          Africa Asia Pacific    Europe    LATAM       USCA
# Segment
# Consumer       1563.48      2817.99  2461.320  1192.52  6719.9808
# Corporate      2597.28      2939.31  1424.850  1035.58  8399.9760
# ...

# %%
import seaborn as sns
sns.heatmap(pd.crosstab([data2.Market, data2.Category], data2.Segment), cmap="YlGnBu", annot=True, cbar=False)

# %%
pd.crosstab(data2.Market, data2.Category, normalize=True)
# Out:
# Category      Furniture  Office Supplies  Technology
# Market
# Africa         0.012303         0.059368    0.017762
# Asia Pacific   0.056990         0.162702    0.059154
# Europe         0.034646         0.150478    0.043556
# LATAM          0.046442         0.114291    0.039969
# USCA           0.041860         0.123201    0.037278

# %%
import pandas as  pd
import numpy as np
import seaborn as sns
titanic = pd.read_excel('C:\\Users\\sh.noori\\Desktop\\titanic.xlsx')
titanic.head(5)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic.groupby('sex')[['survived']].mean()
# Out:
#         survived
# sex
# female  0.727468
# male    0.190985

# %%
titanic.groupby(['sex', 'pclass'])['survived'].aggregate('mean').unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.965278  0.886792  0.490741
# male    0.340782  0.146199  0.152130

# %%
titanic.pivot_table('survived', index='sex', columns='pclass')
# Out:
# pclass         1         2         3
# sex
# female  0.965278  0.886792  0.490741
# male    0.340782  0.146199  0.152130

# %%
age = pd.cut(titanic['age'], [0, 18, 80])

titanic.pivot_table('survived', ['sex', age], 'pclass')
# Out:
# pclass                  1         2         3
# sex    age
# female (0, 18]   0.923077  0.952381  0.534483
#        (18, 80]  0.966667  0.878049  0.436170
# male   (0, 18]   0.750000  0.523810  0.208333
#        (18, 80]  0.328671  0.087591  0.158845

# %%
fare = pd.qcut(titanic['fare'], 2)
titanic.pivot_table('survived', ['sex', age], [fare, 'pclass'])
# Out:
# fare            (-0.001, 14.454]                     (14.454, 512.329]  \
# pclass                         1         2         3                 1
# sex    age
# female (0, 18]               NaN  0.750000  0.666667          0.923077
#        (18, 80]              NaN  0.866667  0.437500          0.966667
# male   (0, 18]               NaN  0.000000  0.264706          0.750000
#        (18, 80]              0.2  0.119048  0.154167          0.333333
#
# fare
# pclass                  2         3
# sex    age
# female (0, 18]   1.000000  0.392857
#        (18, 80]  0.884615  0.433333
# male   (0, 18]   0.687500  0.157895
#        (18, 80]  0.037736  0.194444

# %%
titanic.pivot_table(index='sex', columns='pclass', aggfunc={'survived':sum, 'fare':'mean'})
# Out:
#               fare                       survived
# pclass           1          2          3        1   2    3
# sex
# female  109.412385  23.234827  15.324250      139  94  106
# male     69.888385  19.904946  12.415462       61  25   75

# %%
import pandas as pd
birth= pd.read_csv('C:\\Users\\sh.noori\\Desktop\\births.csv')
birth.head(5)
# Out:
#    year  month  day gender  births
# 0  1969      1  1.0      F    4046
# 1  1969      1  1.0      M    4440
# 2  1969      1  2.0      F    4454
# 3  1969      1  2.0      M    4548
# 4  1969      1  3.0      F    4548

# %%
birth['decade'] = 10 * (birth['year'] // 10)
birth.pivot_table('births', index='decade', columns='gender', aggfunc='sum')
# Out:
# gender         F         M
# decade
# 1960     1753634   1846572
# 1970    16263075  17121550
# 1980    18310351  19243452
# 1990    19479454  20420553
# 2000    18229309  19106428

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
sns.set() # use Seaborn styles
birth.pivot_table('births', index='year', columns='gender', aggfunc='sum').plot()
plt.ylabel('total births per year');
