# %% [markdown]
# ## import csv files

# %%
import pandas as pd

# %%
test = pd.read_csv('C:\\Users\\erfan\\Desktop\\customer_bank_data.csv')

# %%
test.tail(20)
# Out:
#      CUSTOMERID  AGE       EDUCATION  YEARSEMPLOYED  INCOME  CARDDEBT  \
# 830         831   33          SCHOOL             13      52     2.714
# 831         832   27  UNDER GRADUATE              8      18     0.401
# 832         833   36  UNDER GRADUATE              7      43     2.649
# 833         834   30        DOCTRATE              7      30     0.264
# 834         835   28  UNDER GRADUATE              3      36     0.384
# 835         836   21   POST GRADUATE              0      41     2.367
# 836         837   23  UNDER GRADUATE              3      24     0.552
# 837         838   23          SCHOOL              7      22     0.849
# 838         839   26          SCHOOL             10      25     1.306
# 839         840   31          SCHOOL              8      22     0.370
# 840         841   38   POST GRADUATE             13      25     0.343
# 841         842   29   POST GRADUATE              7      63     0.572
# ...

# %%
test2= pd.read_csv('C:\\Users\\erfan\\Desktop\\customer_bank_data.csv', header=None)
test2
# Out:
#               0    1               2              3       4         5  \
# 0    CUSTOMERID  AGE       EDUCATION  YEARSEMPLOYED  INCOME  CARDDEBT
# 1             1   41  UNDER GRADUATE              6      19     0.124
# 2             2   47          SCHOOL             26     100     4.582
# 3             3   33  UNDER GRADUATE             10      57     6.111
# 4             4   29  UNDER GRADUATE              4      19     0.681
# 5             5   47          SCHOOL             31     253     9.308
# 6             6   40          SCHOOL             23      81     0.998
# 7             7   38  UNDER GRADUATE              4      56     0.442
# 8             8   42   POST GRADUATE              0      64     0.279
# 9             9   26          SCHOOL              5      18     0.575
# 10           10   47   POST GRADUATE             23     115     0.653
# 11           11   44   POST GRADUATE              8      88     0.285
# ...

# %%
test2= pd.read_csv('C:\\Users\\erfan\\Desktop\\customer_bank_data.csv', header=None,
                     names= ['A', 'B', 'C', 'D', 'name', 'Reza', 'Mashin', 'F', 'G'])
test2.head()
# Out:
#             A    B               C              D    name      Reza  \
# 0  CUSTOMERID  AGE       EDUCATION  YEARSEMPLOYED  INCOME  CARDDEBT
# 1           1   41  UNDER GRADUATE              6      19     0.124
# 2           2   47          SCHOOL             26     100     4.582
# 3           3   33  UNDER GRADUATE             10      57     6.111
# 4           4   29  UNDER GRADUATE              4      19     0.681
#
#       Mashin          F        G
# 0  OTHERDEBT  DEFAULTED  ADDRESS
# 1      1.073          0   NBA001
# 2      8.218          0   NBA021
# 3      5.802          1   NBA013
# 4      0.516          0   NBA009

# %%
test3= pd.read_csv('C:\\Users\\erfan\\Desktop\\customer_bank_data.csv', nrows= 15)
                     
test3
# Out:
#     CUSTOMERID  AGE       EDUCATION  YEARSEMPLOYED  INCOME  CARDDEBT  \
# 0            1   41  UNDER GRADUATE              6      19     0.124
# 1            2   47          SCHOOL             26     100     4.582
# 2            3   33  UNDER GRADUATE             10      57     6.111
# 3            4   29  UNDER GRADUATE              4      19     0.681
# 4            5   47          SCHOOL             31     253     9.308
# 5            6   40          SCHOOL             23      81     0.998
# 6            7   38  UNDER GRADUATE              4      56     0.442
# 7            8   42   POST GRADUATE              0      64     0.279
# 8            9   26          SCHOOL              5      18     0.575
# 9           10   47   POST GRADUATE             23     115     0.653
# 10          11   44   POST GRADUATE              8      88     0.285
# 11          12   34  UNDER GRADUATE              9      40     0.374
# 12          13   24          SCHOOL              7      18     0.526
# ...

# %% [markdown]
# ## import excel files

# %%
test4 = pd.read_excel('C:\\Users\\erfan\\Desktop\\Global Superstore Orders 2016.xlsx',
                        sheet_name = 'People')
test4
# Out:
#                   Person             Region
# 0      Marilène Rousseau          Caribbean
# 1       Andile Ihejirika     Central Africa
# 2      Nicodemo Bautista    Central America
# 3         Cansu Peynirci       Central Asia
# 4             Lon Bonher         Central US
# 5           Wasswa Ahmed     Eastern Africa
# 6          Hadia Bousaid       Eastern Asia
# 7         Lynne Marchand     Eastern Canada
# 8          Oxana Lagunov     Eastern Europe
# 9          Dolores Davis         Eastern US
# 10      Lindiwe Afolayan       North Africa
# 11          Miina Nylund    Northern Europe
# 12           Kauri Anaru            Oceania
# 13       Vasco Magalhães      South America
# 14      Preecha Metharom  Southeastern Asia
# 15          Nora Cuijper    Southern Africa
# 16  Chandrakant Chaudhri      Southern Asia
# 17           Gavino Bove    Southern Europe
# 18       Flannery Newton        Southern US
# 19        Katlego Akosua     Western Africa
# ...

# %%
test5= pd.read_excel('C:\\Users\\erfan\\Desktop\\Global Superstore Orders 2016.xlsx', skiprows=5, header=None, usecols=(1,2))
test5.head(10)
# Out:
#                           0          1
# 0   SG-2014-RH9495111-41948 2014-11-05
# 1    IN-2014-JM156557-41818 2014-06-28
# 2   IN-2012-TS2134092-41219 2012-11-06
# 3   IN-2013-MB1808592-41378 2013-04-14
# 4  CA-2014-AB10015140-41954 2014-11-11
# 5  CA-2012-AB10015140-40974 2012-03-06
# 6  CA-2012-AB10015140-40974 2012-03-06
# 7    ID-2013-AJ107801-41383 2013-04-19
# 8   SA-2012-MM7260110-41269 2012-12-26
# 9   MX-2013-VF2171518-41591 2013-11-13

# %% [markdown]
# ## import URL files

# %%
import pandas as pd
test6 = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv', header=None,
                      names= ['A', 'B', 'C', 'D'])
test6
# Out:
#        A    B    C               D
# 5.1  3.5  1.4  0.2     Iris-setosa
# 4.9  3.0  1.4  0.2     Iris-setosa
# 4.7  3.2  1.3  0.2     Iris-setosa
# 4.6  3.1  1.5  0.2     Iris-setosa
# 5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...             ...
# 6.7  3.0  5.2  2.3  Iris-virginica
# 6.3  2.5  5.0  1.9  Iris-virginica
# 6.5  3.0  5.2  2.0  Iris-virginica
# 6.2  3.4  5.4  2.3  Iris-virginica
# 5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
test7= pd.read_table('C:\\Users\\erfan\\Desktop\\iris.txt', sep=',')
# sep = '\t', '\s+', '@', '-', '_' 
test7.head()
# Out:
#    sepal length  sepal width  petal length  petal width     label
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## import SAS files

# %%
#test8= pd.read_sas('آدرس فایل با فرمت مربوطه')

# %% [markdown]
# ## import STATA files

# %%
#test9= pd.read_stata('آدرس فایل با فرمت مرتبط')
